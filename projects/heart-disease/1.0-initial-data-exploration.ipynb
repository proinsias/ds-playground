# %%
from pathlib import Path

# %%
repo_dir = Path.cwd().parents[0]
repo_dir
# Out:
# PosixPath('/Users/ftod/GitHub/heart-disease')

# %%
import sys

sys.path.insert(0, f"{repo_dir}")

import missingno as msno
import numpy as np
import pandas as pd
import ydata_profiling

import heart_disease.constants as hdc
import heart_disease.data.get_dataset as hddgd  # FIXME: Add get_dataset to heart_disease?
# Out:
# /Users/ftod/.pyenv/versions/3.10.2/envs/ds/lib/python3.10/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /Users/ftod/.pyenv/versions/3.10.2/envs/ds/lib/python3.10/site-packages/visions/backends/shared/nan_handling.py:51: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def hasna(x: np.ndarray) -> bool:

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load data

# %%
hddgd.get_dataset()
combined_df = hddgd.validate_and_combine_dataset()
# Out:
# Downloaded the zip file to /Users/ftod/GitHub/heart-disease/data/raw/heart_disease.zip .
# Extracted files to /Users/ftod/GitHub/heart-disease/data/raw .

# %%
print(combined_df.shape)
combined_df.head()
# Out:
# (920, 15)
#    age     sex                cp  trestbps  chol                       fbs  \
# 0   63    male    typical angina       145   233  high fasting blood sugar
# 1   67    male      asymptomatic       160   286   low fasting blood sugar
# 2   67    male      asymptomatic       120   229   low fasting blood sugar
# 3   37    male  non-anginal pain       130   250   low fasting blood sugar
# 4   41  female   atypical angina       130   204   low fasting blood sugar
#
#                         restecg  thalach                       exang  oldpeak  \
# 0  left ventricular hypertrophy      150  no exercise induced angina      2.3
# 1  left ventricular hypertrophy      108     exercise induced angina      1.5
# 2  left ventricular hypertrophy      129     exercise induced angina      2.6
# 3                        normal      187  no exercise induced angina      3.5
# 4  left ventricular hypertrophy      172  no exercise induced angina      1.4
#
#          slope  ca               thal     source  target
# 0  downsloping   0       fixed defect  cleveland       0
# 1         flat   3             normal  cleveland       1
# 2         flat   2  reversable defect  cleveland       1
# 3  downsloping   0             normal  cleveland       0
# 4    upsloping   0             normal  cleveland       0

# %%
combined_df.dtypes
# Out:
# age            Int64
# sex         category
# cp          category
# trestbps       Int64
# chol           Int64
# fbs         category
# restecg     category
# thalach        Int64
# exang       category
# oldpeak      float64
# slope       category
# ca             Int64
# thal        category
# source        object
# target         int64
# dtype: object

# %%
combined_df.describe(include="all").T
# Out:
#           count unique                         top  freq        mean  \
# age       920.0   <NA>                        <NA>  <NA>    53.51087
# sex         920      2                        male   726         NaN
# cp          920      4                asymptomatic   496         NaN
# trestbps  861.0   <NA>                        <NA>  <NA>  132.132404
# chol      890.0   <NA>                        <NA>  <NA>  199.130337
# fbs         920      3     low fasting blood sugar   692         NaN
# restecg     920      4                      normal   551         NaN
# thalach   865.0   <NA>                        <NA>  <NA>  137.545665
# exang       920      3  no exercise induced angina   528         NaN
# oldpeak   858.0    NaN                         NaN   NaN    0.878788
# slope       920      4                        flat   345         NaN
# ca        310.0   <NA>                        <NA>  <NA>    0.703226
# thal        920      4               missing value   486         NaN
# source      920      4                   cleveland   303         NaN
# target    920.0    NaN                         NaN   NaN    0.553261
#
#                 std   min    25%    50%    75%    max
# age        9.424685  28.0   47.0   54.0   60.0   77.0
# sex             NaN   NaN    NaN    NaN    NaN    NaN
# cp              NaN   NaN    NaN    NaN    NaN    NaN
# trestbps   19.06607   0.0  120.0  130.0  140.0  200.0
# chol      110.78081   0.0  175.0  223.0  268.0  603.0
# fbs             NaN   NaN    NaN    NaN    NaN    NaN
# restecg         NaN   NaN    NaN    NaN    NaN    NaN
# thalach   25.926276  60.0  120.0  140.0  157.0  202.0
# exang           NaN   NaN    NaN    NaN    NaN    NaN
# oldpeak    1.091226  -2.6    0.0    0.5    1.5    6.2
# slope           NaN   NaN    NaN    NaN    NaN    NaN
# ca         1.046951   0.0    0.0    0.0    1.0    9.0
# thal            NaN   NaN    NaN    NaN    NaN    NaN
# source          NaN   NaN    NaN    NaN    NaN    NaN
# target     0.497426   0.0    0.0    1.0    1.0    1.0

# %%
combined_df["target"].value_counts()
# Out:
# target
# 1    509
# 0    411
# Name: count, dtype: int64

# %% [markdown]
# # Data profile

# %% [markdown]
# ## ydata-profiling

# %%
profile = ydata_profiling.ProfileReport(
    df=combined_df,
    title="Profiling Report",
    explorative=True,
)

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# ## vscode-data-wrangler

# %%
# See <https://github.com/microsoft/vscode-data-wrangler> for instructions.
combined_df.head()
# Out:
#    age     sex                cp  trestbps  chol                       fbs  \
# 0   63    male    typical angina       145   233  high fasting blood sugar
# 1   67    male      asymptomatic       160   286   low fasting blood sugar
# 2   67    male      asymptomatic       120   229   low fasting blood sugar
# 3   37    male  non-anginal pain       130   250   low fasting blood sugar
# 4   41  female   atypical angina       130   204   low fasting blood sugar
#
#                         restecg  thalach                       exang  oldpeak  \
# 0  left ventricular hypertrophy      150  no exercise induced angina      2.3
# 1  left ventricular hypertrophy      108     exercise induced angina      1.5
# 2  left ventricular hypertrophy      129     exercise induced angina      2.6
# 3                        normal      187  no exercise induced angina      3.5
# 4  left ventricular hypertrophy      172  no exercise induced angina      1.4
#
#          slope  ca               thal     source  target
# 0  downsloping   0       fixed defect  cleveland       0
# 1         flat   3             normal  cleveland       1
# 2         flat   2  reversable defect  cleveland       1
# 3  downsloping   0             normal  cleveland       0
# 4    upsloping   0             normal  cleveland       0

# %% [markdown]
# # Missing data

# %%
# List of columns with nulls.
combined_df.columns[pd.isnull(combined_df).sum() > 0].values
# Out:
# array(['trestbps', 'chol', 'thalach', 'oldpeak', 'ca'], dtype=object)

# %%
# Patterns in data completion.
msno.matrix(combined_df);

# %%
# Nullity by column.
msno.bar(combined_df);
# Out:
# <Axes: >

# %%
# Measures nullity correlation: how strongly the presence or absence of one variable affects the presence of another.
msno.heatmap(combined_df);
# Out:
# <Axes: >

# %%
# Reveals trends deeper than the pairwise ones visible in the correlation heatmap.
msno.dendrogram(combined_df);
# Out:
# <Axes: >
